# %%
# !pip install -q dvc dvc-gdrive
print("✅ DVC installed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.1/470.1 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.2/214.2 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.2/74.2 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 49.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/Sai-light-18/mlops-misinformation-detection.git
# %cd mlops-misinformation-detection
print("✅ Repo cloned")
# Out:
# Cloning into 'mlops-misinformation-detection'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 36 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 1.11 MiB | 4.67 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/mlops-misinformation-detection
# ✅ Repo cloned

# %%
# !git config --global user.email "gaddamsaijyothi@gmail.com"
# !git config --global user.name "Sai-light-18"
print("✅ Git configured")
# Out:
# ✅ Git configured

# %%
# !dvc init
# !git add .dvc
# !git commit -m "Initialise DVC"
print("✅ DVC initialised")
# Out:
# ERROR: failed to initiate DVC - '.dvc' exists. Use `-f` to force.
# [main 566dffa] Initialise DVC
#  3 files changed, 6 insertions(+)
#  create mode 100644 .dvc/.gitignore
#  create mode 100644 .dvc/config
#  create mode 100644 .dvcignore
# ✅ DVC initialised

# %%
import os

# Make sure we are inside the repo
os.chdir('/content/mlops-misinformation-detection')
print(f"Current directory: {os.getcwd()}")

# Track with DVC
# !dvc add data/raw/train.tsv
# !dvc add data/raw/valid.tsv
# !dvc add data/raw/test.tsv

print("✅ Data files tracked by DVC")
# Out:
# Current directory: /content/mlops-misinformation-detection
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# ERROR:  output 'data/raw/train.tsv' is already tracked by SCM (e.g. Git).
#     You can remove it from Git, then add to DVC.
#         To stop tracking from Git:
#             git rm -r --cached 'data/raw/train.tsv'
#             git commit -m "stop tracking data/raw/train.tsv"
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# ERROR:  output 'data/raw/valid.tsv' is already tracked by SCM (e.g. Git).
#     You can remove it from Git, then add to DVC.
#         To stop tracking from Git:
#             git rm -r --cached 'data/raw/valid.tsv'
#             git commit -m "stop tracking data/raw/valid.tsv"
# ⠋ Checking graph
# ...

# %%
import shutil, os

# First check where your TSV files are
import glob
tsv_files = glob.glob('/content/**/*.tsv', recursive=True)
print("Found TSV files:")
for f in tsv_files:
    print(f"  {f}")
# Out:
# Found TSV files:
#   /content/mlops-misinformation-detection/data/raw/test.tsv
#   /content/mlops-misinformation-detection/data/raw/valid.tsv
#   /content/mlops-misinformation-detection/data/raw/train.tsv

# %%
# !git rm -r --cached data/raw/train.tsv
# !git rm -r --cached data/raw/valid.tsv
# !git rm -r --cached data/raw/test.tsv
# !git commit -m "Remove TSV files from Git tracking — moving to DVC"
print("✅ Files removed from Git tracking")
# Out:
# rm 'data/raw/train.tsv'
# rm 'data/raw/valid.tsv'
# rm 'data/raw/test.tsv'
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@1a14a21556a3.(none)')
# ✅ Files removed from Git tracking

# %%
# !dvc add data/raw/train.tsv
# !dvc add data/raw/valid.tsv
# !dvc add data/raw/test.tsv
print("✅ Files now tracked by DVC")
# Out:
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Adding data/raw/train.tsv to cache:   0% 0/1 [00:00<?, ?file/s]
# Adding data/raw/train.tsv to cache:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
#
#   0% 0/1 [00:00<?, ?files/s]
#   0% 0/1 [00:00<?, ?files/s{'info': ''}]
# Adding...: 100% 1/1 [00:00<00:00, 14.91file/s{'info': ''}]
#
# To track the changes with git, run:
#
# 	git add data/raw/train.tsv.dvc data/raw/.gitignore
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Adding data/raw/valid.tsv to cache:   0% 0/1 [00:00<?, ?file/s]
# Adding data/raw/valid.tsv to cache:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
#
#   0% 0/1 [00:00<?, ?files/s]
# ...

# %%
# !git add data/raw/train.tsv.dvc
# !git add data/raw/valid.tsv.dvc
# !git add data/raw/test.tsv.dvc
# !git add .gitignore
# !git commit -m "Add DVC tracking for LIAR dataset files"
print("✅ DVC metadata committed to Git")
# Out:
# fatal: pathspec '.gitignore' did not match any files
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@1a14a21556a3.(none)')
# ✅ DVC metadata committed to Git

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.makedirs('/content/drive/MyDrive/dvc-storage', exist_ok=True)

# !dvc remote add -d gdrive /content/drive/MyDrive/dvc-storage
# !dvc push

print("✅ Data pushed to Google Drive")
# Out:
# Mounted at /content/drive
# Setting 'gdrive' as a default remote.
# ...
# Pushing
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#  33% 1/3 [00:00<00:01,  1.35files/s{'info': ''}]
#  67% 2/3 [00:01<00:00,  1.80files/s{'info': ''}]
# 100% 3/3 [00:01<00:00,  1.87files/s{'info': ''}]
# Pushing
# Everything is up to date.
# ✅ Data pushed to Google Drive

# %%
# !git push origin main
print("✅ DVC setup complete and pushed to GitHub")
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
# ✅ DVC setup complete and pushed to GitHub

# %%
# Install Docker in Colab
# !apt-get install -y docker.io 2>/dev/null

# Clone your repo
# !git clone https://github.com/Sai-light-18/mlops-misinformation-detection.git
# %cd mlops-misinformation-detection

# Copy data files
# !cp /content/train.tsv data/raw/
# !cp /content/valid.tsv data/raw/
# !cp /content/test.tsv data/raw/

# Build Docker image
# !docker build -t mlops-misinformation .
print("✅ Docker image built")

# Run container
# !docker run --rm \
    -v $(pwd)/data:/app/data \
    -v $(pwd)/results:/app/results \
    mlops-misinformation \
    python src/baseline.py
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base iptables
#   libip6tc2 libjansson4 libnetfilter-conntrack3 libnfnetlink0 libnftables1
#   libnftnl11 netbase netcat netcat-openbsd runc ubuntu-fan
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ifupdown aufs-tools btrfs-progs
#   cgroupfs-mount | cgroup-lite debootstrap docker-buildx docker-compose-v2
#   docker-doc rinse zfs-fuse | zfsutils firewalld nftables
# The following NEW packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base docker.io
#   iptables libip6tc2 libjansson4 libnetfilter-conntrack3 libnfnetlink0
#   libnftables1 libnftnl11 netbase netcat netcat-openbsd runc ubuntu-fan
# 0 upgraded, 18 newly installed, 0 to remove and 3 not upgraded.
# Need to get 28.6 MB/75.5 MB of archives.
# ...
